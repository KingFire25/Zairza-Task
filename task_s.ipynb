# %% [markdown]
# # Seaborn Exercises
#
# Time to practice your new seaborn skills!

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
# There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
sns.jointplot(x="fare",y="age",data=titanic)

# %%
sns.distplot(titanic.fare,hist=True,kde=False,color="red")
plt.show()

# %%
sns.catplot(x="class",y="age",kind="box",data=titanic)

# %%
sns.catplot(x="class",y="age",kind="swarm",height=5.1,aspect=1.3,data=titanic)

# %%
sns.catplot(x="sex",data=titanic,kind='count')

# %%
d=titanic.corr()
ax = plt.subplots(figsize=(7, 5))
sns.heatmap(d,cmap="RdBu_r")
# Out:
# <AxesSubplot:>

# %%
sns.FacetGrid(data=titanic,row="sex",col="age")

# %% [markdown]
# # Great Job!
